# %%
from dao.mongodbdao import MongoDBDao
from tfidf.TF_IDF import TF_IDF
import numpy as np 

dao = MongoDBDao({
    "host": "127.0.0.1",
    "db": "default",
    "wordindex_collection": "wordindex",
    "pagedetails_collection": "pagedetails",
    "username": "root",
    "password": "spezanw"
})

# %% [markdown]
# # Speedtest

# %%
import datetime

def measure(f):
    t1 = datetime.datetime.now()
    res=f()
    t2 = datetime.datetime.now()
    d = (t2-t1).total_seconds()*1000
    return d

def f():
    tfidf = TF_IDF(dao, verbose=False)

def speed_test(n_runs):
    times = []
    for i in range(n_runs):
        times.append(measure(f))
        print("run", i,"took", times[-1], "milliseconds")
    mean_time = np.mean(times)
    print("TF-IDF calculation took an average time of", mean_time, "milliseconds")

n_runs = 100
speed_test(n_runs)
# Out:
# run 0 took 2921.034 milliseconds
# run 1 took 2819.587 milliseconds
# run 2 took 3024.216 milliseconds
# run 3 took 2930.607 milliseconds
# run 4 took 2848.802 milliseconds
# run 5 took 2677.292 milliseconds
# run 6 took 2604.992 milliseconds
# run 7 took 2602.809 milliseconds
# run 8 took 2693.574 milliseconds
# run 9 took 2880.507 milliseconds
# run 10 took 2659.815 milliseconds
# run 11 took 2718.0240000000003 milliseconds
# run 12 took 2717.5440000000003 milliseconds
# run 13 took 2656.4990000000003 milliseconds
# run 14 took 2665.6870000000004 milliseconds
# run 15 took 2720.658 milliseconds
# run 16 took 2711.048 milliseconds
# run 17 took 2627.221 milliseconds
# run 18 took 2737.7180000000003 milliseconds
# run 19 took 2738.3320000000003 milliseconds
# run 20 took 2798.4179999999997 milliseconds
# run 21 took 2816.8669999999997 milliseconds
# run 22 took 2710.293 milliseconds
# run 23 took 2502.194 milliseconds
# run 24 took 2408.614 milliseconds
# run 25 took 2547.712 milliseconds
# run 26 took 2649.188 milliseconds
# run 27 took 2606.011 milliseconds
# run 28 took 2635.632 milliseconds
# run 29 took 2493.884 milliseconds
# run 30 took 2659.073 milliseconds
# run 31 took 2734.239 milliseconds
# run 32 took 2670.5860000000002 milliseconds
# run 33 took 2705.464 milliseconds
# run 34 took 2710.214 milliseconds
# run 35 took 2793.317 milliseconds
# run 36 took 2722.8210000000004 milliseconds
# run 37 took 2748.21 milliseconds
# run 38 took 2605.672 milliseconds
# run 39 took 2668.4649999999997 milliseconds
# run 40 took 2753.239 milliseconds
# run 41 took 2632.5440000000003 milliseconds
# run 42 took 2732.329 milliseconds
# run 43 took 2660.596 milliseconds
# run 44 took 2725.793 milliseconds
# run 45 took 2781.6580000000004 milliseconds
# run 46 took 2776.185 milliseconds
# run 47 took 2650.737 milliseconds
# run 48 took 2695.804 milliseconds
# run 49 took 2295.6949999999997 milliseconds
# run 50 took 2408.84 milliseconds
# run 51 took 2636.739 milliseconds
# run 52 took 2678.5969999999998 milliseconds
# run 53 took 2604.915 milliseconds
# run 54 took 2746.419 milliseconds
# run 55 took 2668.924 milliseconds
# run 56 took 2709.7850000000003 milliseconds
# run 57 took 2490.122 milliseconds
# run 58 took 2713.0040000000004 milliseconds
# run 59 took 2661.07 milliseconds
# run 60 took 2671.17 milliseconds
# run 61 took 2598.592 milliseconds
# run 62 took 2686.799 milliseconds
# run 63 took 2638.856 milliseconds
# run 64 took 2697.9320000000002 milliseconds
# run 65 took 2703.788 milliseconds
# run 66 took 2726.8500000000004 milliseconds
# run 67 took 2778.615 milliseconds
# run 68 took 2771.518 milliseconds
# run 69 took 2707.611 milliseconds
# run 70 took 2695.38 milliseconds
# run 71 took 2764.7889999999998 milliseconds
# run 72 took 2805.189 milliseconds
# run 73 took 2861.322 milliseconds
# run 74 took 2703.913 milliseconds
# run 75 took 2565.3269999999998 milliseconds
# run 76 took 2852.561 milliseconds
# run 77 took 2725.0519999999997 milliseconds
# run 78 took 2712.176 milliseconds
# run 79 took 2691.7580000000003 milliseconds
# run 80 took 2714.645 milliseconds
# run 81 took 2649.9809999999998 milliseconds
# run 82 took 2594.262 milliseconds
# run 83 took 2411.306 milliseconds
# run 84 took 2579.665 milliseconds
# run 85 took 2596.214 milliseconds
# run 86 took 2665.827 milliseconds
# run 87 took 2682.3959999999997 milliseconds
