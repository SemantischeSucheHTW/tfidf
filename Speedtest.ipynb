# %%
from dao.mongodbdao import MongoDBDao
from tfidf.TF_IDF import TF_IDF
import numpy as np 

dao = MongoDBDao({
    "host": "127.0.0.1",
    "db": "default",
    "wordindex_collection": "wordindex",
    "pagedetails_collection": "pagedetails",
    "username": "root",
    "password": "spezanw"
})

# %% [markdown]
# # Speedtest

# %%
import datetime

def measure(f):
    t1 = datetime.datetime.now()
    res=f()
    t2 = datetime.datetime.now()
    d = (t2-t1).total_seconds()*1000
    return d

def f():
    tfidf = TF_IDF(dao, verbose=False)

def speed_test(n_runs):
    times = []
    for i in range(n_runs):
        times.append(measure(f))
        print("run", i,"took", times[-1], "milliseconds")
    mean_time = np.mean(times)
    print("TF-IDF calculation took an average time of", mean_time, "milliseconds")

n_runs = 100
speed_test(n_runs)
# Out:
# run 0 took 3261.098 milliseconds
# run 1 took 3333.616 milliseconds
# run 2 took 3133.579 milliseconds
# run 3 took 3054.848 milliseconds
# run 4 took 3162.9610000000002 milliseconds
# run 5 took 3429.84 milliseconds
# run 6 took 3159.373 milliseconds
# run 7 took 3231.874 milliseconds
# run 8 took 3437.683 milliseconds
# run 9 took 3431.698 milliseconds
# run 10 took 3468.953 milliseconds
# run 11 took 3112.913 milliseconds
# run 12 took 3134.403 milliseconds
# run 13 took 3620.645 milliseconds
# run 14 took 3290.756 milliseconds
# run 15 took 3308.017 milliseconds
# run 16 took 3067.733 milliseconds
# run 17 took 3247.7200000000003 milliseconds
# run 18 took 3506.907 milliseconds
# run 19 took 3907.304 milliseconds
# run 20 took 3233.1240000000003 milliseconds
# run 21 took 3494.552 milliseconds
# run 22 took 3187.6000000000004 milliseconds
# run 23 took 3397.218 milliseconds
# run 24 took 3599.846 milliseconds
# run 25 took 3462.27 milliseconds
# run 26 took 3255.544 milliseconds
# run 27 took 3210.369 milliseconds
# run 28 took 2922.8900000000003 milliseconds
# run 29 took 3094.674 milliseconds
# run 30 took 3496.3920000000003 milliseconds
# run 31 took 2956.623 milliseconds
# run 32 took 3212.4799999999996 milliseconds
# run 33 took 3281.934 milliseconds
# run 34 took 3204.04 milliseconds
# run 35 took 3200.996 milliseconds
# run 36 took 3435.1569999999997 milliseconds
# run 37 took 3237.688 milliseconds
# run 38 took 3917.335 milliseconds
# run 39 took 3632.027 milliseconds
